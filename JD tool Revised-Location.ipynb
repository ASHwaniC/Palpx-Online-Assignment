# %% [markdown]
# # Used Libraries

# %%
import pandas as pd
import numpy as np
import docx

# %% [markdown]
# # Importing the File
# The file should be in docx format. Taking all the text free data in a string.

# %%
doc = docx.Document('c:\\Users\\ashwani\\Marketing JD 1.docx')
fullText = []
for para in doc.paragraphs:
    fullText.append(para.text)
l=' '.join(fullText)
l=l.lower()
l
# Out:
# 'job description welcome to jobwebkenya.com. this website helps you to achieve your career dream by linking you to vacancies from top companies in kenya. job seekers are also exposed to best articles for career growth and development. we strongly advise graduates not to pay money before getting a job. report fraudulent jobs to company: location: nairobi, nairobi county, kenya state: job type: full-time job category: job title: marketing manager reports to: head of business development core value behaviors teamwork: ”we work together to make jamii bora better” innovation: “we are driven by creativity, innovation and continuous improvement” professionalism: “we are qualified, skilled and committed to serve our customers” integrity: “how we do business is as important as the business we do so we do the right thing always” job purpose: the marketing manager will be the main driver for the marketing, public relations and communication strategy and will contribute to the bank strategy to “grow market share by building our reputation as an efficient, innovative and customer centric enterprise bank” key responsibilities develop and execute the banks branding strategy to ensure clear and visible standard brand application, signage, merchandising, stationery across the network develop and implement events management strategy including management of bank events such as press conferences, product & branch launches, media briefs both externally & internally development and execution of the banks social media and website strategy to ensure development of an up-to-date and informative website & social media platforms; development & execution of the social media strategy main activities embed strategic marketing by implementing digital marketing, events, campaigns and brand awareness by focusing on how to develop competitive advantage into the changing marketplace and leveraging on the banks distinctive capabilities to drive value design and implement the jamii bora bank brand strategy enhance creation by creating, communicating, delivering, and offering solutions that have value for customers, shareholders and partners build the jamii bora brand to ensure that the bank is top of mind as an enterprise bank develop the go to market strategy for new and existing products and develop and execute above the line and below the line brand and product awareness strategies set up, maintain and develop processes necessary to support all activities in the area of marketing, communications and public relations and regularly create marketing/public relations strategy that will allow jbb leadership to cultivate and enhance meaningful relationships with targeted, high-level external audiences, including the media and key stakeholders, including corporate and government partners develop all elements of jbb’s social business, designing and driving jbb social media strategy and tactics oversee development of all jbb’s print communications including the annual report, marketing collateral materials and electronic communications including jbb’s website and new media actively engage, cultivate, and manage press relationships to ensure coverage surrounding jbb programs, special events, public announcements, and other projects establishes and maintains a consistent corporate image throughout all product lines, promotional materials, and events design and create product/service awareness material to ensure availability of product fliers & posters and adoption of cost effective platforms such as website, social media development and execution of the banks social media and website strategy to ensure development of an up-to-date and informative website & social media platforms; development & execution of the social media strategy develop and implement internal and external communications strategy, including design and content management for internal e-newsletter (jamii yetu), development of press releases, customer email bursts, bulk sms content, posters and fliers dev ...

# %% [markdown]
# # Replacing

# %%
l=l.replace('one','1')
l=l.replace('two','2')
l=l.replace('three','3')
l=l.replace('four','4')
l=l.replace('five','5')
l=l.replace('six','6')
l=l.replace('seven','7')
l=l.replace('eight','8')
l=l.replace('nine','9')
l=l.replace('ten','10')
l=l.replace('eleven','11')
l=l.replace('twelve','12')
l=l.replace('thirteen','13')
l=l.replace('fourteen','14')
l=l.replace('fifteen','15')
l=l.replace('sixteen','16')
l=l.replace('seventeen','17')
l=l.replace('eighteen','18')
l=l.replace('nineteen','19')
l=l.replace('twenty','20')

# %% [markdown]
# # Reading the CSV file of Cities

# %%
loc=pd.read_csv('c:\\Users\\ashwani\\India Cities.csv')
loc=loc.apply(lambda col: col.str.lower())
loc1=list(loc.address)

# %%
#split the jd with space
l1=l.split(' ') 
b1=[]
for i in range (len(l1)):
    b1.append(l1[i:i+1]) 
    b1.append(l1[i-1:i+1])
d2=[]
for sublist in b1:
    d2.append(' '.join(sublist))
#b1 is the list of all matched words
b1=[]
for i in range (len(d2)):
    for b in range (len(loc1)):
        if d2[i]==loc1[b]:
            b1.append(d2[i])

# %%
#counting the occurance of job location in JD
m={}
e={}
count=0
o=[]
for item in b1:
    if item in e:
        e[item]+=1
    else:
        e[item]=1
a1_sorted_keys = sorted(e, key=e.get, reverse=True)
for r in a1_sorted_keys:
    m={'key':r,'count':e[r]}
    o.append(m)
    
import pandas as pd
df=pd.DataFrame(o)
dfl=df[:2]
#df1 is the resultant job location

# %%
#list of words
a5=['experience','minimum','maximum']
b2=[]
for i in range (len(d2)):
    for b in range (len(a5)):
        if d2[i]==a5[b]:
            b2.append(d2[i:i+1])
            b2.append(d2[i-1:i+2])
            b2.append(d2[i-2:i+1])
            b2.append(d2[i:i+3])
            b2.append(d2[i:i+2])
            b2.append(d2[i-1:i+1])
            b2.append(d2[i-3:i+1])
            b2.append(d2[i-2:i+2])
            b2.append(d2[i-1:i+3])
            b2.append(d2[i:i+4])
            b2.append(d2[i-4:i+1])
            b2.append(d2[i-3:i+2])
            b2.append(d2[i-2:i+3])
            b2.append(d2[i-1:i+4])
            b2.append(d2[i:i+5])
b2
d2=[]
for sublist in b2:
    d2.append(' '.join(sublist))
b3=[ ]
for i in range(len(d2)):
    b3.append(d2[i].split(' '))
# Out:
# [['experience'],
#  ['qualification', 'and', 'experience', 'and', 'experience'],
#  ['and', 'qualification', 'and', 'experience'],
#  ['experience', 'and', 'experience', 'requirements'],
#  ['experience', 'and', 'experience'],
#  ['qualification', 'and', 'experience'],
#  ['objective', 'qualification', 'and', 'qualification', 'and', 'experience'],
#  ['and', 'qualification', 'and', 'experience', 'and', 'experience'],
#  ['qualification', 'and', 'experience', 'and', 'experience', 'requirements'],
#  ['experience',
#   'and',
#   'experience',
#   'requirements',
#   'experience',
#   'requirements'],
#  ['qualification',
#   'objective',
#   'qualification',
#   'and',
#   'qualification',
#   'and',
#   'experience'],
#  ['objective',
#   'qualification',
#   'and',
#   'qualification',
#   'and',
#   'experience',
#   'and',
#   'experience'],
#  ['and',
#   'qualification',
#   'and',
#   'experience',
#   'and',
#   'experience',
#   'requirements'],
#  ['qualification',
#   'and',
#   'experience',
#   'and',
#   'experience',
#   'requirements',
#   'experience',
#   'requirements'],
#  ['experience',
#   'and',
#   'experience',
#   'requirements',
#   'experience',
#   'requirements',
#   'university'],
#  ['experience'],
#  ['advantage', 'demonstrated', 'experience', 'demonstrated', 'experience'],
#  ['demonstrated', 'advantage', 'demonstrated', 'experience'],
#  ['experience', 'demonstrated', 'experience', 'and'],
#  ['experience', 'demonstrated', 'experience'],
#  ['advantage', 'demonstrated', 'experience'],
#  ['added',
#   'advantage',
#   'demonstrated',
#   'advantage',
#   'demonstrated',
#   'experience'],
#  ['demonstrated',
#   'advantage',
#   'demonstrated',
#   'experience',
#   'demonstrated',
#   'experience'],
#  ['advantage',
#   'demonstrated',
#   'experience',
#   'demonstrated',
#   'experience',
#   'and'],
#  ['experience', 'demonstrated', 'experience', 'and', 'experience', 'and'],
#  ['advantage',
#   'added',
#   'advantage',
#   'demonstrated',
#   'advantage',
#   'demonstrated',
#   'experience'],
#  ['added',
#   'advantage',
#   'demonstrated',
#   'advantage',
#   'demonstrated',
#   'experience',
#   'demonstrated',
#   'experience'],
#  ['demonstrated',
#   'advantage',
#   'demonstrated',
#   'experience',
#   'demonstrated',
#   'experience',
#   'and'],
#  ['advantage',
#   'demonstrated',
#   'experience',
#   'demonstrated',
#   'experience',
#   'and',
#   'experience',
#   'and'],
#  ['experience',
#   'demonstrated',
#   'experience',
#   'and',
#   'experience',
#   'and',
#   'leadership'],
#  ['minimum'],
#  ['marketing', 'programs', 'minimum', 'programs', 'minimum'],
#  ['programs', 'marketing', 'programs', 'minimum'],
#  ['minimum', 'programs', 'minimum', '5'],
#  ['minimum', 'programs', 'minimum'],
#  ['marketing', 'programs', 'minimum'],
#  ['and', 'marketing', 'programs', 'marketing', 'programs', 'minimum'],
#  ['programs', 'marketing', 'programs', 'minimum', 'programs', 'minimum'],
#  ['marketing', 'programs', 'minimum', 'programs', 'minimum', '5'],
#  ['minimum', 'programs', 'minimum', '5', 'minimum', '5'],
#  ['marketing',
#   'and',
#   'marketing',
#   'programs',
#   'marketing',
#   'programs',
#   'minimum'],
#  ['and',
#   'marketing',
#   'programs',
#   'marketing',
#   'programs',
#   'minimum',
#   'programs',
#   'minimum'],
#  ['programs', 'marketing', 'programs', 'minimum', 'programs', 'minimum', '5'],
#  ['marketing',
#   'programs',
#   'minimum',
#   'programs',
#   'minimum',
#   '5',
#   'minimum',
#   '5'],
#  ['minimum', 'programs', 'minimum', '5', 'minimum', '5', 'years'],
#  ['experience'],
#  ['5', 'years', 'experience', 'years', 'experience'],
#  ['years', '5', 'years', 'experience'],
#  ['experience', 'years', 'experience', 'in'],
#  ['experience', 'years', 'experience'],
#  ['5', 'years', 'experience'],
#  ['minimum', '5', 'years', '5', 'years', 'experience'],
#  ['years', '5', 'years', 'experience', 'years', 'experience'],
#  ['5', 'years', 'experience', 'years', 'experience', 'in'],
#  ['experience', 'years', 'experience', 'in', 'experience', 'in'],
#  ['5', 'minimum', '5', 'years', '5', 'years', 'experience'],
#  ['minimum', '5', 'years', '5', 'years', 'experience', 'years', 'experience'],
#  ['years', '5', 'years', 'experience', 'years', 'experience', 'in'],
#  ['5', 'years', 'experience', 'years', 'experience', 'in', 'experience', 'in'],
#  ['experience', 'years', 'experience', 'in', 'experience', 'in', 'a']]

# %%
b4=[]
for words in b3:
    for word in words:
        b4.append(word)
b4=list(set(b4))
b4=sorted(b4)
type(b4[0])
m={}
o=[]
for i in b4:
    m={'word':i}
    o.append(m)
df3=pd.DataFrame(o)
dfe=df3[df3['word'].astype(str).str.isdigit()]
#df3 is the year of experience required

# %% [markdown]
# # Replacing all the skill words with the Salad Bar Mapping.

# %%
l=l.replace('marketing','Marketing ')
l=l.replace('sale','Sales ')
l=l.replace('marketing management','Planning & Execution ')
l=l.replace('digital marketing','Online/digital marketing ')
l=l.replace('business development','Business Development/Partnerships ')
l=l.replace('brand management','Branding ')
l=l.replace('product management','Product Management/Product Manager ')
l=l.replace('social media','Digital Marketing/Social Media ')
l=l.replace('marketing strategy','Strategy/Planning ')
l=l.replace('market research','Market sizing ')
l=l.replace('btl','Selecting marketing channels ')
l=l.replace('branding','Branding ')
l=l.replace('strategy','Strategic decisions ')
l=l.replace('atl','Selecting marketing channels ')
l=l.replace('advertising','Advertising ')
l=l.replace('pr ','Public Relations(PR) ')
l=l.replace('promotion','Selecting marketing channels ')
l=l.replace('campaign','Ignore ')
l=l.replace('product marketing','Marketing ')
l=l.replace('seo','Online/digital marketing ')
l=l.replace('marketing communication','Communications ')
l=l.replace('business development manager','Business Development/Partnerships ')
l=l.replace('sales management','Ignore ')
l=l.replace('event','Ignore ')
l=l.replace('sem','Online/digital marketing ')
l=l.replace('marketing planning','Planning & Execution ')
l=l.replace('lead generation','Lead generation ')
l=l.replace('online marketing','Online/digital marketing ')
l=l.replace('marketing campaigns','Ignore ')
l=l.replace('email marketing','Online/digital marketing ')
l=l.replace('project management','Project/Program Manager ')
l=l.replace('product development','Product Management/Product Manager ')
l=l.replace('digital media','Online/digital marketing ')
l=l.replace('client servicing','Understanding customers ')
l=l.replace('sales strategy','Strategic decisions ')
l=l.replace('accountant','Financial accounting ')
l=l.replace('selling','Sales ')
l=l.replace('key accounts management','Account manager ')
l=l.replace('brand communication','Branding ')
l=l.replace('campaign management','Ignore ')
l=l.replace('public relation','Public Relations(PR) ')
l=l.replace('b2b','Sales-B2C/D2C/Teritary ')
l=l.replace('social media marketing','Online/digital marketing ')
l=l.replace('brand building','Branding ')
l=l.replace('account management','Account Manager ')
l=l.replace('media planning','Execution plan ')
l=l.replace('brand marketing','Branding ')
l=l.replace('business planning','Strategy/Planning ')
l=l.replace('mba','Ignore ')
l=l.replace('set()','Ignore ')
l=l.replace('new product launch','Product Management/Product Manager ')
l=l.replace('relationship management','Managing multiple stakeholders ')
l=l.replace('corporate sale','Sales-B2B/Institutional/Enterprise ')
l=l.replace('brand planning','Brandng ')
l=l.replace('brand strategy','Strategic decisions ')
l=l.replace('channel sale','Sales- Channel/B2B2C/Distributor/Retail/Second ')
l=l.replace('crm','CRM ')
l=l.replace('website','Ignore ')
l=l.replace('business analyst','Ignore ')
l=l.replace('media relations','Public Relations(PR) ')
l=l.replace('channel partner','Sales- Channel/B2B2C/Distributor/Retail/Second ')
l=l.replace('sales marketing','Marketing ')
l=l.replace('new product','Product Management/Product Manager ')
l=l.replace('nan','Ignore ')
l=l.replace('operation','Operations ')
l=l.replace('budgeting','Budgeting ')
l=l.replace('macrom','Communications ')
l=l.replace('financial','Ignore ')
l=l.replace('area sales manager','Sales- Channel/B2B2C/Distributor/Retail/Second ')
l=l.replace('marketing programs','Marketng ')
l=l.replace('alliance','Partnership/Relations ')
l=l.replace('category management','Ignore ')
l=l.replace('iim','Ignore ')
l=l.replace('team management','Managing people ')
l=l.replace('google analytics','Online/digital marketing ')
l=l.replace('ad sales','Sales- Channel/B2B2C/Distributor/Retail/Second ')
l=l.replace('distribution','Sales- Channel/B2B2C/Distributor/Retail/Second ')
l=l.replace('channel marketing','Selecting marketing channels ')
l=l.replace('trade marketing','Marketing ') 
l=l.replace('strategic planning','Strategic decisions ')
l=l.replace('market intelligence','Market sizing ')
l=l.replace('key accounts','Account Manager ')
l=l.replace('direct marketing','Marketing ')
l=l.replace('promotional','Public Relations(PR) ')
l=l.replace('fmcg','Ignore ')
l=l.replace('pharma','Pharmaceuticals ')
l=l.replace('customer service','Understanding customers ')
l=l.replace('pricing','Pricing ')
l=l.replace('marketing manager','Marketing ')
l=l.replace('publicity','Public Relations(PR) ')
l=l.replace('product sales','Sales ')
l=l.replace('marketing initiatives','Entrepreneurial ')
l=l.replace('planning','Exection plan ')
l=l.replace('revenue generation','Sales ')
l=l.replace('patnership','Managing multiple stakeholders ')
l=l.replace('marketing budget','Budgeting ')
l=l.replace('business strategy','Strategic decisions ')
l=l.replace('content marketing','Selecting marketing channels ')
l=l.replace('ppc','Online/digital marketing ')
l=l.replace('communication skills','Comunications ')
l=l.replace('b2b sales','Sales-B2B/Institutional/Enterprise ')
l=l.replace('market analyst','Market sizing ')
l=l.replace('corporate communication','Comunications ')
l=l.replace('sale manager','Sales ')
l=l.replace('b2b marketing','Marketing ')
l=l.replace('data analytics','Data Analysis ')
l=l.replace('cold calling','Understanding customers ')
l=l.replace('brand promotion','Branding ')
l=l.replace('region','Ignore ')
l=l.replace('product portfolio','Ignore ')
l=l.replace('field sales','Sales ')
l=l.replace('customer relationship','Understanding customers ')
l=l.replace('brand positioning','Branding ')
l=l.replace('online reputation management','Difficult conversations ')
l=l.replace('marketing head','Strategic decisions ')
l=l.replace('senior management','Strategic decisions ')
l=l.replace('event management','Events ')
l=l.replace('product life circle','Product Management/Product Manager ')
l=l.replace('marketing executive','Strategic decisions ')
l=l.replace('fresher','Ignore ')
l=l.replace('part time','Ignore ')
l=l.replace('sale executive','Sales ')
l=l.replace('freelancing','Ignore ')
l=l.replace('facebook','Online/digital marketing ')
l=l.replace('bcom','Ignore ')
l=l.replace('business development executive','Business Development/Partnerships ')
l=l.replace('bm','Ignore ')
l=l.replace('content writing','Copyediting ')
l=l.replace('search engine optimization','Online/digital marketing ')
l=l.replace('bbm','Ignore ')
l=l.replace('direct sales','Selecting marketing channels ')
l=l.replace('sales executive','Sales ')
l=l.replace('internet marketing','Online/digital marketing ')
l=l.replace('marketing sales','Sales ')
l=l.replace('back office','Ignore ')
l=l.replace('retail sales','Sales- Channel/B2B2C/Distributor/Retail/Secondary ')
l=l.replace('recruitment','Human Resources / HR-Recruiting ')
l=l.replace('data entry','Administrative ')
l=l.replace('bmm','Ignore ')
l=l.replace('hr','Human Resources ')
l=l.replace('medium','Ignore ')
l=l.replace('networking','Patnerships/Relationships ')
l=l.replace('online','Online/digital marketing ')
l=l.replace('twitter','Online/digital marketing ')
l=l.replace('photoshop','Software ')
l=l.replace('travel','Ignore ')
l=l.replace('software development','IT Software Engineer/CTO ')
l=l.replace('engineering','Engineering ')
l=l.replace('management','Ignore ')
l=l.replace('ms office','MS Office ')
l=l.replace('web technologies','Information Services and Technology(Tech) ')
l=l.replace('internet','Ignore ')
l=l.replace('btech','Ignore ')
l=l.replace('bba','Ignore ')
l=l.replace('seo executive','Online/digital marketing ')
l=l.replace('product strategy','Strategic decisions ')
l=l.replace('social networking','Online/digital marketing ')
l=l.replace('bde','Business Development/Partnerships ')
l=l.replace('google adwords','Online/digital marketing ')
l=l.replace('brand awareness','Branding ')
l=l.replace('sales executive','Sales ')
l=l.replace('telemarketing','Selecting marketing channels ')
l=l.replace('idea','Entrepreneurial ')
l=l.replace('data analysis','Data Analysis ')
l=l.replace('new business','Business Development/Partnerships ')
l=l.replace('customer experience','Customer Service / Customer Care ')
l=l.replace('analytical','Analytics ')
l=l.replace('exhibition','Ignore ')
l=l.replace('customer acquisition','Lead generation ')
l=l.replace('media sales','Sales- Channel/B2B2C/Distributor/Retail/Secondary ')
l=l.replace('consultant','Ignore ')
l=l.replace('web analytics','Online/digital marketing ')
l=l.replace('ms excel','Excel ')
l=l.replace('client management','Managing multiple stakeholders ')
l=l.replace('sales process','Sales ')
l=l.replace('research','Research ')
l=l.replace('cross selling','Sales - Other ')
l=l.split(' ')

# %% [markdown]
# # Taking all the possible words in a list (d1) that can occur in (l) of length upto 5 words

# %%
b=[]

for i in range (len(l)):
    b.append(l[i:i+1])
    b.append(l[i-1:i+2])
    b.append(l[i-2:i+1])
    b.append(l[i:i+3])
    b.append(l[i:i+2])
    b.append(l[i-1:i+1])
    b.append(l[i-3:i+1])
    b.append(l[i-2:i+2])
    b.append(l[i-1:i+3])
    b.append(l[i:i+4])
    b.append(l[i-4:i+1])
    b.append(l[i-3:i+2])
    b.append(l[i-2:i+3])
    b.append(l[i-1:i+4])
    b.append(l[i:i+5])
    
    
        
d1=[]
for sublist in b:
    d1.append(' '.join(sublist))
d1
# Out:
# ['job',
#  '',
#  '',
#  'job description welcome',
#  'job description',
#  '',
#  '',
#  '',
#  '',
#  'job description welcome to',
#  '',
#  '',
#  '',
#  '',
#  'job description welcome to jobwebkenya.com.',
#  'description',
#  'job description welcome',
#  '',
#  'description welcome to',
#  'description welcome',
#  'job description',
#  '',
#  '',
#  'job description welcome to',
#  'description welcome to jobwebkenya.com.',
#  '',
#  '',
#  '',
#  'job description welcome to jobwebkenya.com.',
#  'description welcome to jobwebkenya.com. this',
#  'welcome',
#  'description welcome to',
#  'job description welcome',
#  'welcome to jobwebkenya.com.',
#  'welcome to',
#  'description welcome',
#  '',
#  'job description welcome to',
#  'description welcome to jobwebkenya.com.',
#  'welcome to jobwebkenya.com. this',
#  '',
#  '',
#  'job description welcome to jobwebkenya.com.',
#  'description welcome to jobwebkenya.com. this',
#  'welcome to jobwebkenya.com. this Ignore',
#  'to',
#  'welcome to jobwebkenya.com.',
#  'description welcome to',
#  'to jobwebkenya.com. this',
#  'to jobwebkenya.com.',
#  'welcome to',
#  'job description welcome to',
#  'description welcome to jobwebkenya.com.',
#  'welcome to jobwebkenya.com. this',
#  'to jobwebkenya.com. this Ignore',
#  '',
#  'job description welcome to jobwebkenya.com.',
#  'description welcome to jobwebkenya.com. this',
#  'welcome to jobwebkenya.com. this Ignore',
#  'to jobwebkenya.com. this Ignore ',
#  'jobwebkenya.com.',
#  'to jobwebkenya.com. this',
#  'welcome to jobwebkenya.com.',
#  'jobwebkenya.com. this Ignore',
#  'jobwebkenya.com. this',
#  'to jobwebkenya.com.',
#  'description welcome to jobwebkenya.com.',
#  'welcome to jobwebkenya.com. this',
#  'to jobwebkenya.com. this Ignore',
#  'jobwebkenya.com. this Ignore ',
#  'job description welcome to jobwebkenya.com.',
#  'description welcome to jobwebkenya.com. this',
#  'welcome to jobwebkenya.com. this Ignore',
#  'to jobwebkenya.com. this Ignore ',
#  'jobwebkenya.com. this Ignore  helps',
#  'this',
#  'jobwebkenya.com. this Ignore',
#  'to jobwebkenya.com. this',
#  'this Ignore ',
#  'this Ignore',
#  'jobwebkenya.com. this',
#  'welcome to jobwebkenya.com. this',
#  'to jobwebkenya.com. this Ignore',
#  'jobwebkenya.com. this Ignore ',
#  'this Ignore  helps',
#  'description welcome to jobwebkenya.com. this',
#  'welcome to jobwebkenya.com. this Ignore',
#  'to jobwebkenya.com. this Ignore ',
#  'jobwebkenya.com. this Ignore  helps',
#  'this Ignore  helps you',
#  'Ignore',
#  'this Ignore ',
#  'jobwebkenya.com. this Ignore',
#  'Ignore  helps',
#  'Ignore ',
#  'this Ignore',
#  'to jobwebkenya.com. this Ignore',
#  'jobwebkenya.com. this Ignore ',
#  'this Ignore  helps',
#  'Ignore  helps you',
#  'welcome to jobwebkenya.com. this Ignore',
#  'to jobwebkenya.com. this Ignore ',
#  'jobwebkenya.com. this Ignore  helps',
#  'this Ignore  helps you',
#  'Ignore  helps you to',
#  '',
#  'Ignore  helps',
#  'this Ignore ',
#  ' helps you',
#  ' helps',
#  'Ignore ',
#  'jobwebkenya.com. this Ignore ',
#  'this Ignore  helps',
#  'Ignore  helps you',
#  ' helps you to',
#  'to jobwebkenya.com. this Ignore ',
#  'jobwebkenya.com. this Ignore  helps',
#  'this Ignore  helps you',
#  'Ignore  helps you to',
#  ' helps you to achieve',
#  'helps',
#  ' helps you',
#  'Ignore  helps',
#  'helps you to',
#  'helps you',
#  ' helps',
#  'this Ignore  helps',
#  'Ignore  helps you',
#  ' helps you to',
#  'helps you to achieve',
#  'jobwebkenya.com. this Ignore  helps',
#  'this Ignore  helps you',
#  'Ignore  helps you to',
#  ' helps you to achieve',
#  'helps you to achieve your',
#  'you',
#  'helps you to',
#  ' helps you',
#  'you to achieve',
#  'you to',
#  'helps you',
#  'Ignore  helps you',
#  ' helps you to',
#  'helps you to achieve',
#  'you to achieve your',
#  'this Ignore  helps you',
#  'Ignore  helps you to',
#  ' helps you to achieve',
#  'helps you to achieve your',
#  'you to achieve your career',
#  'to',
#  'you to achieve',
#  'helps you to',
#  'to achieve your',
#  'to achieve',
#  'you to',
#  ' helps you to',
#  'helps you to achieve',
#  'you to achieve your',
#  'to achieve your career',
#  'Ignore  helps you to',
#  ' helps you to achieve',
#  'helps you to achieve your',
#  'you to achieve your career',
#  'to achieve your career dream',
#  'achieve',
#  'to achieve your',
#  'you to achieve',
#  'achieve your career',
#  'achieve your',
#  'to achieve',
#  'helps you to achieve',
#  'you to achieve your',
#  'to achieve your career',
#  'achieve your career dream',
#  ' helps you to achieve',
#  'helps you to achieve your',
#  'you to achieve your career',
#  'to achieve your career dream',
#  'achieve your career dream by',
#  'your',
#  'achieve your career',
#  'to achieve your',
#  'your career dream',
#  'your career',
#  'achieve your',
#  'you to achieve your',
#  'to achieve your career',
#  'achieve your career dream',
#  'your career dream by',
#  'helps you to achieve your',
#  'you to achieve your career',
#  'to achieve your career dream',
#  'achieve your career dream by',
#  'your career dream by linking',
#  'career',
#  'your career dream',
#  'achieve your career',
#  'career dream by',
#  'career dream',
#  'your career',
#  'to achieve your career',
#  'achieve your career dream',
#  'your career dream by',
#  'career dream by linking',
#  'you to achieve your career',
#  'to achieve your career dream',
#  'achieve your career dream by',
#  'your career dream by linking',
#  'career dream by linking you',
#  'dream',
#  'career dream by',
#  'your career dream',
#  'dream by linking',
#  'dream by',
#  'career dream',
#  'achieve your career dream',
#  'your career dream by',
#  'career dream by linking',
#  'dream by linking you',
#  'to achieve your career dream',
#  'achieve your career dream by',
#  'your career dream by linking',
#  'career dream by linking you',
#  'dream by linking you to',
#  'by',
#  'dream by linking',
#  'career dream by',
#  'by linking you',
#  'by linking',
#  'dream by',
#  'your career dream by',
#  'career dream by linking',
#  'dream by linking you',
#  'by linking you to',
#  'achieve your career dream by',
#  'your career dream by linking',
#  'career dream by linking you',
#  'dream by linking you to',
#  'by linking you to vacancies',
#  'linking',
#  'by linking you',
#  'dream by linking',
#  'linking you to',
#  'linking you',
#  'by linking',
#  'career dream by linking',
#  'dream by linking you',
#  'by linking you to',
#  'linking you to vacancies',
#  'your career dream by linking',
#  'career dream by linking you',
#  'dream by linking you to',
#  'by linking you to vacancies',
#  'linking you to vacancies from',
#  'you',
#  'linking you to',
#  'by linking you',
#  'you to vacancies',
#  'you to',
#  'linking you',
#  'dream by linking you',
#  'by linking you to',
#  'linking you to vacancies',
#  'you to vacancies from',
#  'career dream by linking you',
#  'dream by linking you to',
#  'by linking you to vacancies',
#  'linking you to vacancies from',
#  'you to vacancies from top',
#  'to',
#  'you to vacancies',
#  'linking you to',
#  'to vacancies from',
#  'to vacancies',
#  'you to',
#  'by linking you to',
#  'linking you to vacancies',
#  'you to vacancies from',
#  'to vacancies from top',
#  'dream by linking you to',
#  'by linking you to vacancies',
#  'linking you to vacancies from',
#  'you to vacancies from top',
#  'to vacancies from top companies',
#  'vacancies',
#  'to vacancies from',
#  'you to vacancies',
#  'vacancies from top',
#  'vacancies from',
#  'to vacancies',
#  'linking you to vacancies',
#  'you to vacancies from',
#  'to vacancies from top',
#  'vacancies from top companies',
#  'by linking you to vacancies',
#  'linking you to vacancies from',
#  'you to vacancies from top',
#  'to vacancies from top companies',
#  'vacancies from top companies in',
#  'from',
#  'vacancies from top',
#  'to vacancies from',
#  'from top companies',
#  'from top',
#  'vacancies from',
#  'you to vacancies from',
#  'to vacancies from top',
#  'vacancies from top companies',
#  'from top companies in',
#  'linking you to vacancies from',
#  'you to vacancies from top',
#  'to vacancies from top companies',
#  'vacancies from top companies in',
#  'from top companies in kenya.',
#  'top',
#  'from top companies',
#  'vacancies from top',
#  'top companies in',
#  'top companies',
#  'from top',
#  'to vacancies from top',
#  'vacancies from top companies',
#  'from top companies in',
#  'top companies in kenya.',
#  'you to vacancies from top',
#  'to vacancies from top companies',
#  'vacancies from top companies in',
#  'from top companies in kenya.',
#  'top companies in kenya. job',
#  'companies',
#  'top companies in',
#  'from top companies',
#  'companies in kenya.',
#  'companies in',
#  'top companies',
#  'vacancies from top companies',
#  'from top companies in',
#  'top companies in kenya.',
#  'companies in kenya. job',
#  'to vacancies from top companies',
#  'vacancies from top companies in',
#  'from top companies in kenya.',
#  'top companies in kenya. job',
#  'companies in kenya. job seekers',
#  'in',
#  'companies in kenya.',
#  'top companies in',
#  'in kenya. job',
#  'in kenya.',
#  'companies in',
#  'from top companies in',
#  'top companies in kenya.',
#  'companies in kenya. job',
#  'in kenya. job seekers',
#  'vacancies from top companies in',
#  'from top companies in kenya.',
#  'top companies in kenya. job',
#  'companies in kenya. job seekers',
#  'in kenya. job seekers are',
#  'kenya.',
#  'in kenya. job',
#  'companies in kenya.',
#  'kenya. job seekers',
#  'kenya. job',
#  'in kenya.',
#  'top companies in kenya.',
#  'companies in kenya. job',
#  'in kenya. job seekers',
#  'kenya. job seekers are',
#  'from top companies in kenya.',
#  'top companies in kenya. job',
#  'companies in kenya. job seekers',
#  'in kenya. job seekers are',
#  'kenya. job seekers are also',
#  'job',
#  'kenya. job seekers',
#  'in kenya. job',
#  'job seekers are',
#  'job seekers',
#  'kenya. job',
#  'companies in kenya. job',
#  'in kenya. job seekers',
#  'kenya. job seekers are',
#  'job seekers are also',
#  'top companies in kenya. job',
#  'companies in kenya. job seekers',
#  'in kenya. job seekers are',
#  'kenya. job seekers are also',
#  'job seekers are also exposed',
#  'seekers',
#  'job seekers are',
#  'kenya. job seekers',
#  'seekers are also',
#  'seekers are',
#  'job seekers',
#  'in kenya. job seekers',
#  'kenya. job seekers are',
#  'job seekers are also',
#  'seekers are also exposed',
#  'companies in kenya. job seekers',
#  'in kenya. job seekers are',
#  'kenya. job seekers are also',
#  'job seekers are also exposed',
#  'seekers are also exposed to',
#  'are',
#  'seekers are also',
#  'job seekers are',
#  'are also exposed',
#  'are also',
#  'seekers are',
#  'kenya. job seekers are',
#  'job seekers are also',
#  'seekers are also exposed',
#  'are also exposed to',
#  'in kenya. job seekers are',
#  'kenya. job seekers are also',
#  'job seekers are also exposed',
#  'seekers are also exposed to',
#  'are also exposed to best',
#  'also',
#  'are also exposed',
#  'seekers are also',
#  'also exposed to',
#  'also exposed',
#  'are also',
#  'job seekers are also',
#  'seekers are also exposed',
#  'are also exposed to',
#  'also exposed to best',
#  'kenya. job seekers are also',
#  'job seekers are also exposed',
#  'seekers are also exposed to',
#  'are also exposed to best',
#  'also exposed to best articles',
#  'exposed',
#  'also exposed to',
#  'are also exposed',
#  'exposed to best',
#  'exposed to',
#  'also exposed',
#  'seekers are also exposed',
#  'are also exposed to',
#  'also exposed to best',
#  'exposed to best articles',
#  'job seekers are also exposed',
#  'seekers are also exposed to',
#  'are also exposed to best',
#  'also exposed to best articles',
#  'exposed to best articles for',
#  'to',
#  'exposed to best',
#  'also exposed to',
#  'to best articles',
#  'to best',
#  'exposed to',
#  'are also exposed to',
#  'also exposed to best',
#  'exposed to best articles',
#  'to best articles for',
#  'seekers are also exposed to',
#  'are also exposed to best',
#  'also exposed to best articles',
#  'exposed to best articles for',
#  'to best articles for career',
#  'best',
#  'to best articles',
#  'exposed to best',
#  'best articles for',
#  'best articles',
#  'to best',
#  'also exposed to best',
#  'exposed to best articles',
#  'to best articles for',
#  'best articles for career',
#  'are also exposed to best',
#  'also exposed to best articles',
#  'exposed to best articles for',
#  'to best articles for career',
#  'best articles for career growth',
#  'articles',
#  'best articles for',
#  'to best articles',
#  'articles for career',
#  'articles for',
#  'best articles',
#  'exposed to best articles',
#  'to best articles for',
#  'best articles for career',
#  'articles for career growth',
#  'also exposed to best articles',
#  'exposed to best articles for',
#  'to best articles for career',
#  'best articles for career growth',
#  'articles for career growth and',
#  'for',
#  'articles for career',
#  'best articles for',
#  'for career growth',
#  'for career',
#  'articles for',
#  'to best articles for',
#  'best articles for career',
#  'articles for career growth',
#  'for career growth and',
#  'exposed to best articles for',
#  'to best articles for career',
#  'best articles for career growth',
#  'articles for career growth and',
#  'for career growth and development.',
#  'career',
#  'for career growth',
#  'articles for career',
#  'career growth and',
#  'career growth',
#  'for career',
#  'best articles for career',
#  'articles for career growth',
#  'for career growth and',
#  'career growth and development.',
#  'to best articles for career',
#  'best articles for career growth',
#  'articles for career growth and',
#  'for career growth and development.',
#  'career growth and development. we',
#  'growth',
#  'career growth and',
#  'for career growth',
#  'growth and development.',
#  'growth and',
#  'career growth',
#  'articles for career growth',
#  'for career growth and',
#  'career growth and development.',
#  'growth and development. we',
#  'best articles for career growth',
#  'articles for career growth and',
#  'for career growth and development.',
#  'career growth and development. we',
#  'growth and development. we strongly',
#  'and',
#  'growth and development.',
#  'career growth and',
#  'and development. we',
#  'and development.',
#  'growth and',
#  'for career growth and',
#  'career growth and development.',
#  'growth and development. we',
#  'and development. we strongly',
#  'articles for career growth and',
#  'for career growth and development.',
#  'career growth and development. we',
#  'growth and development. we strongly',
#  'and development. we strongly advise',
#  'development.',
#  'and development. we',
#  'growth and development.',
#  'development. we strongly',
#  'development. we',
#  'and development.',
#  'career growth and development.',
#  'growth and development. we',
#  'and development. we strongly',
#  'development. we strongly advise',
#  'for career growth and development.',
#  'career growth and development. we',
#  'growth and development. we strongly',
#  'and development. we strongly advise',
#  'development. we strongly advise graduates',
#  'we',
#  'development. we strongly',
#  'and development. we',
#  'we strongly advise',
#  'we strongly',
#  'development. we',
#  'growth and development. we',
#  'and development. we strongly',
#  'development. we strongly advise',
#  'we strongly advise graduates',
#  'career growth and development. we',
#  'growth and development. we strongly',
#  'and development. we strongly advise',
#  'development. we strongly advise graduates',
#  'we strongly advise graduates not',
#  'strongly',
#  'we strongly advise',
#  'development. we strongly',
#  'strongly advise graduates',
#  'strongly advise',
#  'we strongly',
#  'and development. we strongly',
#  'development. we strongly advise',
#  'we strongly advise graduates',
#  'strongly advise graduates not',
#  'growth and development. we strongly',
#  'and development. we strongly advise',
#  'development. we strongly advise graduates',
#  'we strongly advise graduates not',
#  'strongly advise graduates not to',
#  'advise',
#  'strongly advise graduates',
#  'we strongly advise',
#  'advise graduates not',
#  'advise graduates',
#  'strongly advise',
#  'development. we strongly advise',
#  'we strongly advise graduates',
#  'strongly advise graduates not',
#  'advise graduates not to',
#  'and development. we strongly advise',
#  'development. we strongly advise graduates',
#  'we strongly advise graduates not',
#  'strongly advise graduates not to',
#  'advise graduates not to pay',
#  'graduates',
#  'advise graduates not',
#  'strongly advise graduates',
#  'graduates not to',
#  'graduates not',
#  'advise graduates',
#  'we strongly advise graduates',
#  'strongly advise graduates not',
#  'advise graduates not to',
#  'graduates not to pay',
#  'development. we strongly advise graduates',
#  'we strongly advise graduates not',
#  'strongly advise graduates not to',
#  'advise graduates not to pay',
#  'graduates not to pay m1y',
#  'not',
#  'graduates not to',
#  'advise graduates not',
#  'not to pay',
#  'not to',
#  'graduates not',
#  'strongly advise graduates not',
#  'advise graduates not to',
#  'graduates not to pay',
#  'not to pay m1y',
#  'we strongly advise graduates not',
#  'strongly advise graduates not to',
#  'advise graduates not to pay',
#  'graduates not to pay m1y',
#  'not to pay m1y before',
#  'to',
#  'not to pay',
#  'graduates not to',
#  'to pay m1y',
#  'to pay',
#  'not to',
#  'advise graduates not to',
#  'graduates not to pay',
#  'not to pay m1y',
#  'to pay m1y before',
#  'strongly advise graduates not to',
#  'advise graduates not to pay',
#  'graduates not to pay m1y',
#  'not to pay m1y before',
#  'to pay m1y before getting',
#  'pay',
#  'to pay m1y',
#  'not to pay',
#  'pay m1y before',
#  'pay m1y',
#  'to pay',
#  'graduates not to pay',
#  'not to pay m1y',
#  'to pay m1y before',
#  'pay m1y before getting',
#  'advise graduates not to pay',
#  'graduates not to pay m1y',
#  'not to pay m1y before',
#  'to pay m1y before getting',
#  'pay m1y before getting a',
#  'm1y',
#  'pay m1y before',
#  'to pay m1y',
#  'm1y before getting',
#  'm1y before',
#  'pay m1y',
#  'not to pay m1y',
#  'to pay m1y before',
#  'pay m1y before getting',
#  'm1y before getting a',
#  'graduates not to pay m1y',
#  'not to pay m1y before',
#  'to pay m1y before getting',
#  'pay m1y before getting a',
#  'm1y before getting a job.',
#  'before',
#  'm1y before getting',
#  'pay m1y before',
#  'before getting a',
#  'before getting',
#  'm1y before',
#  'to pay m1y before',
#  'pay m1y before getting',
#  'm1y before getting a',
#  'before getting a job.',
#  'not to pay m1y before',
#  'to pay m1y before getting',
#  'pay m1y before getting a',
#  'm1y before getting a job.',
#  'before getting a job. report',
#  'getting',
#  'before getting a',
#  'm1y before getting',
#  'getting a job.',
#  'getting a',
#  'before getting',
#  'pay m1y before getting',
#  'm1y before getting a',
#  'before getting a job.',
#  'getting a job. report',
#  'to pay m1y before getting',
#  'pay m1y before getting a',
#  'm1y before getting a job.',
#  'before getting a job. report',
#  'getting a job. report fraudulent',
#  'a',
#  'getting a job.',
#  'before getting a',
#  'a job. report',
#  'a job.',
#  'getting a',
#  'm1y before getting a',
#  'before getting a job.',
#  'getting a job. report',
#  'a job. report fraudulent',
#  'pay m1y before getting a',
#  'm1y before getting a job.',
#  'before getting a job. report',
#  'getting a job. report fraudulent',
#  'a job. report fraudulent jobs',
#  'job.',
#  'a job. report',
#  'getting a job.',
#  'job. report fraudulent',
#  'job. report',
#  'a job.',
#  'before getting a job.',
#  'getting a job. report',
#  'a job. report fraudulent',
#  'job. report fraudulent jobs',
#  'm1y before getting a job.',
#  'before getting a job. report',
#  'getting a job. report fraudulent',
#  'a job. report fraudulent jobs',
#  'job. report fraudulent jobs to',
#  'report',
#  'job. report fraudulent',
#  'a job. report',
#  'report fraudulent jobs',
#  'report fraudulent',
#  'job. report',
#  'getting a job. report',
#  'a job. report fraudulent',
#  'job. report fraudulent jobs',
#  'report fraudulent jobs to',
#  'before getting a job. report',
#  'getting a job. report fraudulent',
#  'a job. report fraudulent jobs',
#  'job. report fraudulent jobs to',
#  'report fraudulent jobs to company:',
#  'fraudulent',
#  'report fraudulent jobs',
#  'job. report fraudulent',
#  'fraudulent jobs to',
#  'fraudulent jobs',
#  'report fraudulent',
#  'a job. report fraudulent',
#  'job. report fraudulent jobs',
#  'report fraudulent jobs to',
#  'fraudulent jobs to company:',
#  'getting a job. report fraudulent',
#  'a job. report fraudulent jobs',
#  'job. report fraudulent jobs to',
#  'report fraudulent jobs to company:',
#  'fraudulent jobs to company: location:',
#  'jobs',
#  'fraudulent jobs to',
#  'report fraudulent jobs',
#  'jobs to company:',
#  'jobs to',
#  'fraudulent jobs',
#  'job. report fraudulent jobs',
#  'report fraudulent jobs to',
#  'fraudulent jobs to company:',
#  'jobs to company: location:',
#  'a job. report fraudulent jobs',
#  'job. report fraudulent jobs to',
#  'report fraudulent jobs to company:',
#  'fraudulent jobs to company: location:',
#  'jobs to company: location: nairobi,',
#  'to',
#  'jobs to company:',
#  'fraudulent jobs to',
#  'to company: location:',
#  'to company:',
#  'jobs to',
#  'report fraudulent jobs to',
#  'fraudulent jobs to company:',
#  'jobs to company: location:',
#  'to company: location: nairobi,',
#  'job. report fraudulent jobs to',
#  'report fraudulent jobs to company:',
#  'fraudulent jobs to company: location:',
#  'jobs to company: location: nairobi,',
#  'to company: location: nairobi, nairobi',
#  'company:',
#  'to company: location:',
#  'jobs to company:',
#  'company: location: nairobi,',
#  'company: location:',
#  'to company:',
#  'fraudulent jobs to company:',
#  'jobs to company: location:',
#  'to company: location: nairobi,',
#  'company: location: nairobi, nairobi',
#  'report fraudulent jobs to company:',
#  'fraudulent jobs to company: location:',
#  'jobs to company: location: nairobi,',
#  'to company: location: nairobi, nairobi',
#  'company: location: nairobi, nairobi county,',
#  'location:',
#  'company: location: nairobi,',
#  'to company: location:',
#  'location: nairobi, nairobi',
#  'location: nairobi,',
#  'company: location:',
#  'jobs to company: location:',
#  'to company: location: nairobi,',
#  'company: location: nairobi, nairobi',
#  'location: nairobi, nairobi county,',
#  'fraudulent jobs to company: location:',
#  'jobs to company: location: nairobi,',
#  'to company: location: nairobi, nairobi',
#  'company: location: nairobi, nairobi county,',
#  'location: nairobi, nairobi county, kenya',
#  'nairobi,',
#  'location: nairobi, nairobi',
#  'company: location: nairobi,',
#  'nairobi, nairobi county,',
#  'nairobi, nairobi',
#  'location: nairobi,',
#  'to company: location: nairobi,',
#  'company: location: nairobi, nairobi',
#  'location: nairobi, nairobi county,',
#  'nairobi, nairobi county, kenya',
#  'jobs to company: location: nairobi,',
#  'to company: location: nairobi, nairobi',
#  'company: location: nairobi, nairobi county,',
#  'location: nairobi, nairobi county, kenya',
#  'nairobi, nairobi county, kenya state:',
#  'nairobi',
#  'nairobi, nairobi county,',
#  'location: nairobi, nairobi',
#  'nairobi county, kenya',
#  'nairobi county,',
#  'nairobi, nairobi',
#  'company: location: nairobi, nairobi',
#  'location: nairobi, nairobi county,',
#  'nairobi, nairobi county, kenya',
#  'nairobi county, kenya state:',
#  'to company: location: nairobi, nairobi',
#  'company: location: nairobi, nairobi county,',
#  'location: nairobi, nairobi county, kenya',
#  'nairobi, nairobi county, kenya state:',
#  'nairobi county, kenya state: job',
#  'county,',
#  'nairobi county, kenya',
#  'nairobi, nairobi county,',
#  'county, kenya state:',
#  'county, kenya',
#  'nairobi county,',
#  'location: nairobi, nairobi county,',
#  'nairobi, nairobi county, kenya',
#  'nairobi county, kenya state:',
#  'county, kenya state: job',
#  'company: location: nairobi, nairobi county,',
#  'location: nairobi, nairobi county, kenya',
#  'nairobi, nairobi county, kenya state:',
#  'nairobi county, kenya state: job',
#  'county, kenya state: job type:',
#  'kenya',
#  'county, kenya state:',
#  'nairobi county, kenya',
#  'kenya state: job',
#  'kenya state:',
#  'county, kenya',
#  'nairobi, nairobi county, kenya',
#  'nairobi county, kenya state:',
#  'county, kenya state: job',
#  'kenya state: job type:',
#  'location: nairobi, nairobi county, kenya',
#  'nairobi, nairobi county, kenya state:',
#  'nairobi county, kenya state: job',
#  'county, kenya state: job type:',
#  'kenya state: job type: full-time',
#  'state:',
#  'kenya state: job',
#  'county, kenya state:',
#  'state: job type:',
#  'state: job',
#  'kenya state:',
#  'nairobi county, kenya state:',
#  'county, kenya state: job',
#  'kenya state: job type:',
#  'state: job type: full-time',
#  'nairobi, nairobi county, kenya state:',
#  'nairobi county, kenya state: job',
#  'county, kenya state: job type:',
#  'kenya state: job type: full-time',
#  'state: job type: full-time job',
#  'job',
#  'state: job type:',
#  'kenya state: job',
#  'job type: full-time',
#  'job type:',
#  'state: job',
#  'county, kenya state: job',
#  'kenya state: job type:',
#  'state: job type: full-time',
#  'job type: full-time job',
#  'nairobi county, kenya state: job',
#  'county, kenya state: job type:',
#  'kenya state: job type: full-time',
#  'state: job type: full-time job',
#  'job type: full-time job category:',
#  'type:',
#  'job type: full-time',
#  'state: job type:',
#  'type: full-time job',
#  'type: full-time',
#  'job type:',
#  'kenya state: job type:',
#  'state: job type: full-time',
#  'job type: full-time job',
#  'type: full-time job category:',
#  'county, kenya state: job type:',
#  'kenya state: job type: full-time',
#  'state: job type: full-time job',
#  'job type: full-time job category:',
#  'type: full-time job category: job',
#  'full-time',
#  'type: full-time job',
#  'job type: full-time',
#  'full-time job category:',
#  'full-time job',
#  'type: full-time',
#  'state: job type: full-time',
#  'job type: full-time job',
#  'type: full-time job category:',
#  'full-time job category: job',
#  'kenya state: job type: full-time',
#  'state: job type: full-time job',
#  'job type: full-time job category:',
#  'type: full-time job category: job',
#  'full-time job category: job title:',
#  'job',
#  'full-time job category:',
#  'type: full-time job',
#  'job category: job',
#  'job category:',
#  'full-time job',
#  'job type: full-time job',
#  'type: full-time job category:',
#  'full-time job category: job',
#  'job category: job title:',
#  'state: job type: full-time job',
#  'job type: full-time job category:',
#  'type: full-time job category: job',
#  'full-time job category: job title:',
#  'job category: job title: Marketing',
#  'category:',
#  'job category: job',
#  'full-time job category:',
#  'category: job title:',
#  'category: job',
#  'job category:',
#  'type: full-time job category:',
#  'full-time job category: job',
#  'job category: job title:',
#  'category: job title: Marketing',
#  'job type: full-time job category:',
#  'type: full-time job category: job',
#  'full-time job category: job title:',
#  'job category: job title: Marketing',
#  'category: job title: Marketing ',
#  'job',
#  'category: job title:',
#  'job category: job',
#  'job title: Marketing',
#  'job title:',
#  'category: job',
#  'full-time job category: job',
#  'job category: job title:',
#  'category: job title: Marketing',
#  'job title: Marketing ',
#  ...]

# %% [markdown]
# # Function
# a1 is containing all the key words for function

# %%
a1=['Administrative',
'Advertising',
'Analytics / Analyst / Research / Business Intelligence',
'Business Development/Partnerships',
'Mechanical Engineer',
'Customer Service / Customer Care',
'Designer / Creative / User Experience (UX)',
'Civil Engineer',
'Fashion Designing / Designer / Merchandising',
'Investing / Investment',
'Lending / Credit / Collections / Risk',
'Financial Strategy / CFO / Financial Planner',
'General Business / Business Unit Head / General Manager',
'Human Resources / HR-Recruiting',
'Human Resources / HR - Other',
'IT Hardware Engineer/CTO',
'IT Software Engineer/CTO',
'Legal, Regulatory',
'Financial Operations / Administrative Finance',
'Manufacturing / Production',
'Marketing',
'Operations',
'Other',
'Product Management/Product Manager',
'Project/Program Manager',
'Public Relations (PR)',
'Purchasing / Purchasor',
'Automation Engineer / QA',
'Sales-B2B/Institutional/Enterprise',
'Sales-B2C/D2C/Tertiary',
'Strategy/Planning',
'Supply Chain / Logistics',
'Training / Trainer',
'Communications / Branding / Content',
'Partnerships/Relationships',
'Sales - Other',
'Digital Marketing / Social Media',
'Front End Engineer / Developer',
'Backend Engineer / Developer',
'Quality Assurance (QA)',
'Inventory Management',
'Service / Tech support',
'Account Manager',
'Electrical Engineer',
'Data / Data Science']

# %% [markdown]
# # Behaviour
# a2 is containing all the key words of Behaviour

# %%
a2=['Conscientious',
'Curious',
'Entrepreneurial',  
'Focus',
'Integrity', 
'Motivated' ,
'Multi-task', 
'Persistent',
'Reliability', 
'Result-oriented', 
'Rigorous',
'Team player',
'Willing to learn', 
'Working with ambiguity']

# %% [markdown]
# # Competency
# a3 is containing all the key words of Competency

# %%
a3=['Administrative',
'Communications',
'Data Analysis',
'Engineering',
'Finance',
'General Mental Ability', 
'Managing People',
'Marketing',
'Planning & Execution', 
'Process Thinking',
'Programming Languages', 
'Research',
'Sales',
'Software']

# %% [markdown]
# # Task
# a4 is containing all the key words of Task

# %%
a4=['HTML',
'Java',
'SQL',
'.NET',
'Active listening',
'Allocating resources',
'Analytics',
'angular js',
'Attention to detail',
'Basic Finance',
'Branding',
'Budgeting', 
'Building awareness',
'Building trust',
'Civil engineering',  
'Collections',
'Conducting interviews', 
'Contracts',
'Conversions',
'Conveying complex ideas',
'Copyediting',
'Difficult conversations', 
'Electrical engineering',
'Events',
'Excel',
'Execution plan', 
'Expenses',
'Financial accounting',
'Financial modeling',
'full stack engineering',
'Fundraising',
'Getting buy-in', 
'Identifying risk', 
'Interpreting data', 
'Investment / Credit decisions', 
'JavaScript',
'Lead generation', 
'Learning quickly', 
'Managing deadlines',
'Managing down',
'Managing multiple stakeholders', 
'Managing peers',
'Managing up',
'Market sizing', 
'Math',
'Mechanical engineering', 
'Meeting targets',
'Negotiating',
'Online/digital marketing', 
'Pattern recognition',
'Pitching',
'Pleasing people',
'Post-Purchase / Engagement',
'PowerPoint',
'Presenting data', 
'Presenting information',
'Pricing',
'Prioritizing tasks',
'Process adherence',
'Process design',
'Process improvements', 
'MS Office',
'Public speaking',
'Quality assurance', 
'Scheduling',
'Secondary research', 
'Selecting marketing channels', 
'Setting targets',
'Strategic decisions', 
'Strategic design',
'Structuring information',
'Supply chain & logistics',
'Synthesizing information',
'Training',
'Travel bookings', 
'Understanding customers', 
'Understanding requirements',  
'Vocabulary',
'Working memory', 
'CRM']

# %%
type(a4)
# Out:
# list

# %% [markdown]
# # b1 is a list of all the key words occuring in the string (l)

# %%
b1=[]

for i in range (len(d1)):
    for b in range (len(a1)):
        if d1[i]==a1[b]:
            b1.append(d1[i])

# %% [markdown]
# # df1 is the dataframe of the top 2 words in function

# %%
m={}
e={}

count=0
o=[]
for item in b1:
    if item in e:
        e[item]+=1
    else:
        e[item]=1
a1_sorted_keys = sorted(e, key=e.get, reverse=True)
for r in a1_sorted_keys:
    m={'key':r,'count':e[r]}
    o.append(m)
    
import pandas as pd
df=pd.DataFrame(o)
df1=df[:2]
df1
# Out:
#    count                                key
# 0     11                          Marketing
# 1      2  Business Development/Partnerships

# %% [markdown]
# # b2 is a list of all the key words of behaviour occuring in the string (l)

# %%
b2=[]

for i in range (len(d1)):
    for b in range (len(a2)):
        if d1[i]==a2[b]:
            b2.append(d1[i])

# %% [markdown]
# # df2 is the dataframe of the top 5 words in Behaviour

# %%
m={}
e={}

count=0
o=[]
for item in b2:
    if item in e:
        e[item]+=1
    else:
        e[item]=1
a1_sorted_keys = sorted(e, key=e.get, reverse=True)
for r in a1_sorted_keys:
    m={'key':r,'count':e[r]}
    o.append(m)
    
import pandas as pd
df=pd.DataFrame(o)
df2=df[:5]
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # b3 is a list of all the key words of competency occuring in the string (l)

# %%
b3=[]

for i in range (len(d1)):
    for b in range (len(a3)):
        if d1[i]==a3[b]:
            b3.append(d1[i])

# %% [markdown]
# # df3 is the dataframe of the top 5 words in Competency

# %%
m={}
e={}

count=0
o=[]
for item in b3:
    if item in e:
        e[item]+=1
    else:
        e[item]=1
a1_sorted_keys = sorted(e, key=e.get, reverse=True)
for r in a1_sorted_keys:
    m={'key':r,'count':e[r]}
    o.append(m)
    
import pandas as pd
df=pd.DataFrame(o)
df3=df[:5]
df3
# Out:
#    count        key
# 0     11  Marketing

# %% [markdown]
# # b4 is a list of all the key words of task occuring in the string (l)

# %%
b4=[]

for i in range (len(d1)):
    for b in range (len(a4)):
        if d1[i]==a4[b]:
            b4.append(d1[i])

# %% [markdown]
# # df4 is the dataframe of the top 5 words in Task

# %%
m={}
e={}

count=0
o=[]
for item in b4:
    if item in e:
        e[item]+=1
    else:
        e[item]=1
a1_sorted_keys = sorted(e, key=e.get, reverse=True)
for r in a1_sorted_keys:
    m={'key':r,'count':e[r]}
    o.append(m)
    
import pandas as pd
df=pd.DataFrame(o)
df4=df[:5]
df4
# Out:
#    count                           key
# 0     28           Strategic decisions
# 1      3  Selecting marketing channels
# 2      2                      Branding

# %% [markdown]
# # Job Location

# %%
dfl
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Required Work  Experience

# %%
dfe
# Out:
#   word
# 0    5
